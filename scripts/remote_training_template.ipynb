# %%
exp = !!!exp!!!
branch = !!!branch!!!
git_user = !!!git_user!!!
git_repo = !!!git_repo!!!

# %% [markdown]
# # Clone git repo

# %%
# %cd ~
# !git clone https://github.com/$git_user/$git_repo >/dev/null
# %cd $git_repo
# !git checkout $branch
# !pip install -e .

# %% [markdown]
# # Setup weights and biases

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
wandb_api_key = user_secrets.get_secret("wandb_api_key")

# !pip install wandb >/dev/null
# !wandb login $wandb_api_key

# %% [markdown]
# # Unzip dataset

# %%
# !tar -xzf /kaggle/input/audio-separation-dataset/data_audio_sep.tgz
# !ls __data_source_separation

# %% [markdown]
# # Launch training

# %%
# !python scripts/audio_separation_train.py -e $exp

# %% [markdown]
# # Prepare outputs

# %%
# !tar -cvzf /kaggle/working/output.tgz __output_audiosep
